# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Avian_influenza_wildlife_surveillance_France_2016_to_2022.csv')

# %%
df.head(10)
# Out:
#     uid             ID Results_of_analysis     Bird_species_FR  CD_nom  \
# 0  3887  44_20221116_B                  HP     Goeland_argente    3302
# 1  3888  26_20220321_A            negative         Milan_royal    2846
# 2  3903  41_20180724_A            negative       Pelican_blanc    2460
# 3  3901  31_20210304_A            negative        Pigeon_biset    3420
# 4  3892  07_20220518_A            negative       Pigeon_ramier    3424
# 5  3896  69_20210524_A            negative  Tourterelle_turque    3431
# 6  3897  69_20160113_A            negative  Tourterelle_turque    3431
# 7  3898  69_20160324_A            negative  Tourterelle_turque    3431
# 8  3899  01_20210204_A            negative  Tourterelle_turque    3431
# 9  3904  2A_20190124_A            negative  Tourterelle_turque    3431
#
#         Bird_species_LAT Bird_family_latin Code_INSEE_municipality  \
# 0       Larus_argentatus           Laridae                   44211
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/wp/zbn26m6571s6h2n7pdfjc_2r0000gn/T/ipykernel_4146/3420287700.py in ?()
# ----> 1 df.unique('Bird-species_fr')
#
# /opt/miniconda3/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'unique'
